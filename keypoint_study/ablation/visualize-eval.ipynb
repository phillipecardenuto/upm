# %%
# %pylab inline
from glob import glob
import sys
import pandas as pd
from pathlib import Path
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Document-level evaluation
# Here we only consider the SPP-ext-v1 dataset

# %%
document_eval = pd.read_csv('docEvaluation2023-06-16_13-38-38.csv').drop(columns=['Unnamed: 0'])

# %%
document_eval.sort_values(by=['global_quality', 'grouping_quality','relationship_quality'], ascending=False)[["alignment","desc","matching","max_queuesize","min_area","min_keypoints","rank_top_k","same_class","global_quality","grouping_quality","relationship_quality"]].head(10)
# Out:
#      alignment             desc matching  max_queuesize  min_area  \
# 61   CV_MAGSAC  vlfeat_sift_heq       BF            300      0.01
# 190  CV_MAGSAC  vlfeat_sift_heq       BF            300      0.01
# 45   CV_MAGSAC  vlfeat_sift_heq       BF            300      0.05
# 117  CV_MAGSAC  vlfeat_sift_heq       BF            300      0.05
# 103  CV_MAGSAC  vlfeat_sift_heq       BF            300      0.01
# 176  CV_MAGSAC  vlfeat_sift_heq       BF            300      0.01
# 64   CV_MAGSAC  vlfeat_sift_heq       BF            500      0.05
# 142  CV_MAGSAC  vlfeat_sift_heq       BF           1000      0.05
# 187  CV_MAGSAC  vlfeat_sift_heq       BF            500      0.05
# 200  CV_MAGSAC  vlfeat_sift_heq       BF           1000      0.05
#
#      min_keypoints  rank_top_k  same_class  global_quality  grouping_quality  \
# 61              20         400        True             1.0               1.0
# 190             10         400        True             1.0               1.0
# 45              10         400        True             1.0               1.0
# 117             20         400        True             1.0               1.0
# 103             10         200        True             1.0               1.0
# 176             20         200        True             1.0               1.0
# 64              10         200        True             1.0               1.0
# 142             10         200        True             1.0               1.0
# 187             20         200        True             1.0               1.0
# 200             20         200        True             1.0               1.0
#
#      relationship_quality
# 61               0.835205
# 190              0.835205
# 45               0.833530
# 117              0.833530
# 103              0.830242
# 176              0.830242
# 64               0.828726
# 142              0.828726
# 187              0.828726
# 200              0.828726

# %%
print(document_eval.sort_values(by=['global_quality', 'grouping_quality','relationship_quality'], ascending=False)[["alignment","desc","matching","max_queuesize","min_area","min_keypoints","rank_top_k","same_class","global_quality","grouping_quality","relationship_quality"]].head(10).to_markdown())
# Out:
# |     | alignment   | desc            | matching   |   max_queuesize |   min_area |   min_keypoints |   rank_top_k | same_class   |   global_quality |   grouping_quality |   relationship_quality |
# |----:|:------------|:----------------|:-----------|----------------:|-----------:|----------------:|-------------:|:-------------|-----------------:|-------------------:|-----------------------:|
# |  61 | CV_MAGSAC   | vlfeat_sift_heq | BF         |             300 |       0.01 |              20 |          400 | True         |                1 |                  1 |               0.835205 |
# | 190 | CV_MAGSAC   | vlfeat_sift_heq | BF         |             300 |       0.01 |              10 |          400 | True         |                1 |                  1 |               0.835205 |
# |  45 | CV_MAGSAC   | vlfeat_sift_heq | BF         |             300 |       0.05 |              10 |          400 | True         |                1 |                  1 |               0.83353  |
# | 117 | CV_MAGSAC   | vlfeat_sift_heq | BF         |             300 |       0.05 |              20 |          400 | True         |                1 |                  1 |               0.83353  |
# | 103 | CV_MAGSAC   | vlfeat_sift_heq | BF         |             300 |       0.01 |              10 |          200 | True         |                1 |                  1 |               0.830242 |
# | 176 | CV_MAGSAC   | vlfeat_sift_heq | BF         |             300 |       0.01 |              20 |          200 | True         |                1 |                  1 |               0.830242 |
# |  64 | CV_MAGSAC   | vlfeat_sift_heq | BF         |             500 |       0.05 |              10 |          200 | True         |                1 |                  1 |               0.828726 |
# | 142 | CV_MAGSAC   | vlfeat_sift_heq | BF         |            1000 |       0.05 |              10 |          200 | True         |                1 |                  1 |               0.828726 |
# | 187 | CV_MAGSAC   | vlfeat_sift_heq | BF         |             500 |       0.05 |              20 |          200 | True         |                1 |                  1 |               0.828726 |
# | 200 | CV_MAGSAC   | vlfeat_sift_heq | BF         |            1000 |       0.05 |              20 |          200 | True         |                1 |                  1 |               0.828726 |

# %% [markdown]
# ## Panel-level evaluation

# %%
panel_eval =  pd.read_csv('panelEvaluation2023-06-16_14-00-44.csv').drop(columns=['Unnamed: 0'])
panel_group_class = pd.read_csv('panelGroupEvaluation2023-06-16_14-00-44.csv').drop(columns=['Unnamed: 0'])
panel_rel_class = pd.read_csv('panelRelationshipEval2023-06-16_14-00-44.csv').drop(columns=['Unnamed: 0'])

# %%
panel_eval.sort_values(by=['global_quality', 'grouping_quality','relationship_quality'], ascending=False)[["alignment","desc","matching","max_queuesize","min_area","min_keypoints","rank_top_k","same_class","global_quality","grouping_quality","relationship_quality"]].head(10)
# Out:
#     alignment  desc matching  max_queuesize  min_area  min_keypoints  \
# 24     CV_RHO  sila       BF            300      0.05             20
# 74     CV_RHO  sila       BF            500      0.05             10
# 150    CV_RHO  sila       BF            300      0.05             10
# 156    CV_RHO  sila       BF           1000      0.05             20
# 188    CV_RHO  sila       BF           1000      0.05             10
# 199    CV_RHO  sila       BF            500      0.05             20
# 32   CV_LMEDS  sila       BF            300      0.05             20
# 84   CV_LMEDS  sila       BF            500      0.05             10
# 109  CV_LMEDS  sila       BF            300      0.05             10
# 138  CV_LMEDS  sila       BF           1000      0.05             10
#
#      rank_top_k  same_class  global_quality  grouping_quality  \
# 24          100        True        0.879518          0.846067
# 74          100        True        0.879518          0.846067
# 150         100        True        0.879518          0.846067
# 156         100        True        0.879518          0.846067
# 188         100        True        0.879518          0.846067
# 199         100        True        0.879518          0.846067
# 32          100        True        0.878606          0.844381
# 84          100        True        0.878606          0.844381
# 109         100        True        0.878606          0.844381
# 138         100        True        0.878606          0.844381
#
#      relationship_quality
# 24               0.722556
# 74               0.722556
# 150              0.722556
# 156              0.722556
# 188              0.722556
# 199              0.722556
# 32               0.725957
# 84               0.725957
# 109              0.725957
# 138              0.725957

# %%
panel_group_class.sort_values(by=['Blots', 'Flow Cytometry','Microscopy'], ascending=False).head(10)
# Out:
#      Microscopy  Flow Cytometry     Blots  desc matching alignment  \
# 29     0.806334        0.764386  0.305381  sila       BF  CV_LMEDS
# 113    0.806334        0.764386  0.305381  sila       BF  CV_LMEDS
# 120    0.806334        0.764386  0.305381  sila       BF  CV_LMEDS
# 167    0.806334        0.764386  0.305381  sila       BF  CV_LMEDS
# 78     0.806270        0.764386  0.305381  sila       BF  CV_LMEDS
# 168    0.806270        0.764386  0.305381  sila       BF  CV_LMEDS
# 32     0.789027        0.764386  0.305381  sila       BF  CV_LMEDS
# 84     0.789027        0.764386  0.305381  sila       BF  CV_LMEDS
# 109    0.789027        0.764386  0.305381  sila       BF  CV_LMEDS
# 138    0.789027        0.764386  0.305381  sila       BF  CV_LMEDS
#
#      rank_top_k  min_keypoints  max_queuesize  min_area  same_class
# 29          200             10            500      0.05        True
# 113         200             20            500      0.05        True
# 120         200             20           1000      0.05        True
# 167         200             10           1000      0.05        True
# 78          200             20            300      0.05        True
# 168         200             10            300      0.05        True
# 32          100             20            300      0.05        True
# 84          100             10            500      0.05        True
# 109         100             10            300      0.05        True
# 138         100             10           1000      0.05        True

# %%
panel_rel_class.sort_values(by=['Blots', 'Flow Cytometry','Microscopy'], ascending=False).head(10)
# Out:
#      Microscopy  Flow Cytometry     Blots  desc matching alignment  \
# 29     0.806334        0.764386  0.305381  sila       BF  CV_LMEDS
# 113    0.806334        0.764386  0.305381  sila       BF  CV_LMEDS
# 120    0.806334        0.764386  0.305381  sila       BF  CV_LMEDS
# 167    0.806334        0.764386  0.305381  sila       BF  CV_LMEDS
# 78     0.806270        0.764386  0.305381  sila       BF  CV_LMEDS
# 168    0.806270        0.764386  0.305381  sila       BF  CV_LMEDS
# 32     0.789027        0.764386  0.305381  sila       BF  CV_LMEDS
# 84     0.789027        0.764386  0.305381  sila       BF  CV_LMEDS
# 109    0.789027        0.764386  0.305381  sila       BF  CV_LMEDS
# 138    0.789027        0.764386  0.305381  sila       BF  CV_LMEDS
#
#      rank_top_k  min_keypoints  max_queuesize  min_area  same_class
# 29          200             10            500      0.05        True
# 113         200             20            500      0.05        True
# 120         200             20           1000      0.05        True
# 167         200             10           1000      0.05        True
# 78          200             20            300      0.05        True
# 168         200             10            300      0.05        True
# 32          100             20            300      0.05        True
# 84          100             10            500      0.05        True
# 109         100             10            300      0.05        True
# 138         100             10           1000      0.05        True
